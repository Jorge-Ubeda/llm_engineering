# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## Your first Frontier LLM Project
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And I also have a [YouTube channel with extra content](https://youtube.com/@edward.donner).
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### If necessary, install Cursor Extensions
#
# 1. From the View menu, select Extensions
# 2. Search for Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. Search for Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import parse_website_contents, parse_letterboxd_rss
from IPython.display import Markdown, display
from openai import OpenAI, AzureOpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_AZURE_ENDPOINT = os.getenv('OPENAI_AZURE_ENDPOINT')
OPENAI_API_VERSION = os.getenv('OPENAI_API_VERSION')

# Check the key

if not OPENAI_API_KEY:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not OPENAI_API_KEY.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif OPENAI_API_KEY.strip() != OPENAI_API_KEY:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
## FOR NEXUS MODEL

openai = AzureOpenAI(
    azure_deployment="gpt-5.1",
    azure_endpoint=OPENAI_AZURE_ENDPOINT,
    api_key=OPENAI_API_KEY,
    api_version=OPENAI_API_VERSION
)

response = openai.chat.completions.create(
    model="patata", #This does not mean anything, it's just a placeholder
    messages=messages, 
    temperature=0.0, 
    max_completion_tokens=1000)
response.choices[0].message.content


## FOR OPENAI ACCOUNT
#openai = OpenAI()
#response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
#response.choices[0].message.content

## FOR LOCAL MODEL
#openai = OpenAI(
#    base_url="http://localhost:11434/v1",
#    api_key="ollama",
#)
#
#response = openai.chat.completions.create(model="phi3:latest", messages=messages)
#response.choices[0].message.content
# Out:
# 'Hi, and welcome! I’m glad you reached out.\n\nWhat would you like to do or talk about first?'

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility
ed = parse_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 600,000 enrolled across 194 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# For more on me and my courses, please
# chat with me and my Digital Avatar here
# .
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 = 4.'

# %% [markdown]
# ## And now let's build useful messages for GPT-4.1-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nSkip to content\nAvatar\nCurriculum\nProficiency\nC4\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of AI startup\nNebula.io\n. I was previously founder and CEO of AI startup untapt,\nacquired in 2021\n, and a Managing Director at JPMorgan.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 600,000 enrolled across 194 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nFor more on me and my courses, please\nchat with me and my Digital Avatar here\n.\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer – RESOURCES\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents – RESOURCES\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production – RESOURCES\nMay 28, 2025\nWhich order to take the AI courses?\nNavigation\nAvatar\nCurriculum\nProficiency\nC4\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook'}]

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url, contains_js=False):
    website = parse_website_contents(url, contains_js)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# 'This site is basically “Ed Donner’s AI Obsession, The Extended Cut.”\n\n- He’s a serial AI startup founder (Nebula.io now, untapt before it got acquired) and ex–JPMorgan MD who escaped finance to play with LLMs full time.\n- He won’t shut up about LLMs so much that his friends forced him onto Udemy, where his courses accidentally became best-sellers with ~600k students worldwide.\n- The site is mostly:\n  - An AI course curriculum and which-order-to-take-them guidance.\n  - Resource pages for various tracks:\n    - **Feb 17, 2026** – “AI Coder: Vibe Coder to Agentic Engineer” resources (turn your ‘vibes-based coding’ into actual agentic systems).\n    - **Jan 4, 2026** – “AI Builder with n8n – Create Agents and Voice Agents” resources.\n    - **Sep 15, 2025** – “AI Engineering MLOps Track – Deploy AI to Production” resources.\n    - **May 28, 2025** – “Which order to take the AI courses?” (for people paralyzed by choice).\n- There’s also “C4 Outsmart,” an arena where LLMs apparently role-play Game of Thrones in a diplomacy/deception deathmatch.\n- Bonus features: a “Digital Avatar” you can chat with instead of the actual human, and the usual social links if you want even more of Ed’s LLM monologues in your feed.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url, contains_js=False):
    summary = summarize(url, contains_js)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# Edward Donner’s site is basically “Hi, I’m obsessed with LLMs and I turned that into a career (and several startups).”
#
# Highlights:
# - He’s co‑founder/CTO of AI startup Nebula.io, previously founded untapt (acquired in 2021), and used to be a Managing Director at JPMorgan—so he’s checked all the LinkedIn flex boxes.
# - He makes Udemy courses on LLMs and AI engineering that somehow roped in ~600,000 students globally, which is both impressive and mildly terrifying.
# - There’s a “Digital Avatar” you can chat with, presumably for when you want Ed but don’t want *actual* Ed.
# - Sections like “Avatar”, “Curriculum”, “Proficiency”, and “C4 Outsmart” suggest tools, tracks, and an LLM battle arena where models practice diplomacy and conniving like it’s AI Survivor.
#
# Recent posts / resources:
# - Feb 17, 2026: “AI Coder: Vibe Coder to Agentic Engineer – RESOURCES” – sounds like “stop vibes-coding with GPT and start building real agents.”
# - Jan 4, 2026: “AI Builder with n8n – Create Agents and Voice Agents – RESOURCES” – wiring up workflows and voice agents with n8n.
# - Sep 15, 2025: “AI Engineering MLOps Track – Deploy AI to Production – RESOURCES” – because your proof-of-concept needs to suffer in production like the rest of us.
# - May 28, 2025: “Which order to take the AI courses?” – the reading order for his AI cinematic universe.
#
# In short: it’s a personal hub for Ed’s AI courses, experiments, and LLM deathmatch arena, plus a contact email for when you want more AI and fewer social skills.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://cnn.com")
# Out:
# This “website” is basically CNN screaming, “NEWS ABOUT EVERYTHING, EVERYWHERE, ALL AT ONCE… and also please rate our ads.”
#
# What it actually is:
# - A global news hub: US, World, Politics, Business, Health, Entertainment, Style, Travel, Sports, Science, Climate, Weather, wars (Ukraine–Russia, Israel–Hamas), World Cup 2026, etc.
# - Multiple editions: US, International, Arabic, Español.
# - Lots of video and live TV options: “Watch,” “Listen,” “Live TV,” plus sign-in and subscription nudges.
# - Topic areas for deep dives: elections, Trump, polls, Epstein files, markets, investing, fitness, food, sleep, mindfulness, relationships, tech, fashion, luxury, architecture, space, climate, and more.
#
# News/announcements actually visible here:
# - Mostly structural: navigation to ongoing coverage of World Cup 2026 and major wars (Ukraine–Russia, Israel–Hamas) — implying these are current big stories.
# - Prominent focus on US politics and Elections 2026, suggesting the site is gearing up for extended election coverage.
#
# And layered on top of all that:
# - A desperate ad feedback form asking if the ad annoyed you, broke the page, or just screamed too loudly — so CNN wants your opinion, but only after the commercial.

# %%
display_summary("https://anthropic.com")
# Out:
# Anthropic’s site is basically: “We make AI, but we promise not to let it blow up civilization.”
#
# - Front and center: they build AI research and products (Claude and its various alter egos: Code, Cowork, Design, Security, Platform) with a big emphasis on *safety at the frontier* and responsible scaling.
# - They’re a public benefit corporation, which is corporate-speak for “we swear we’re the good guys.”
# - Lots of policy and governance candy: constitutions for AI, transparency, trust center, security/compliance, and something ominously named “Policy on the AI Exponential.”
# - Learning section for tutorials, use cases, docs, and Anthropic Academy so you can figure out what to do with all these politely constrained robots.
# - Company section: about, careers, events, news—standard “please come work for us and/or write about us” material.
#
# **News / announcements:**
# - Big highlighted study: *“What 81,000 people want from AI”* — apparently the largest study ever on how AI is messing with shaping lives around the world.
# - Latest release: *Expanding Project Glasswing* (June 2, 2026) — they’re rolling this safety-ish initiative out to ~150 new organizations across more than 15 countries, presumably to help people not use AI like a flamethrower.
#
# In short: serious AI, heavy on safety, many Claude flavors, and a growing international safety project with a dramatic name.

# %%
display_summary("https://www.game.es/")
# Out:
# This is basically Spain’s nerd paradise in website form.
#
# - Sells everything gaming: PS5, Xbox, Nintendo Switch (and the teased Switch 2), PCs, handhelds, monitors, chairs, streaming gear, peripherals… if it lights up and makes noise, it’s probably here.
# - Digital codes buffet: PlayStation, Nintendo eShop, Xbox, Fortnite, Roblox, Netflix, Disney, TikTok, Movistar, DAZN… your wallet cries in multiple formats.
# - Big current highlights:
#   - Grand Theft Auto VI hype front and center (because of course).
#   - Plan Renove PS5 (trade-in/upgrade deal so you can pretend you’re “saving money”).
#   - Assassin’s Creed Black Flag Resynced and EA Sports FC 26, UFC 6, and Marvel’s Wolverine with exclusive GAME DLC.
#   - Samsung 55" TV, 3x2 LEGO offer, Cromos Mundial 2026, and PlayStation gift cards for lazy-but-acceptable gifting.
# - Tons of preorders: Nintendo Switch 2 + Pokémon Pokopia, and various upcoming titles.
# - Second-hand & reacondicionados section so you can buy stuff cheaper and feel morally superior to full-price buyers.
# - Extra nerd bait: LEGO, board games, Funko POPs, collectibles, manga, movies, steelbooks, and merchandising (Star Wars included, obviously).
#
# In short: Spanish all-in-one temple of gaming, geek merch, and digital addictions, with a homepage screaming “please preorder something.”

# %% [markdown]
# ### What happens if I try scraping a website that loads on user's side?
# Some adjustments have been made to the scraper to handle this. Now if a website uses javascript or other client-side rendering, you need to set the `contains_js` parameter to `True` when calling the `parse_website_contents` or `display_summary` functions. Then the website will be rendered completely using a headless browser.

# %%
parse_website_contents("https://quotes.toscrape.com/js/", contains_js=True)
# Out:
# "Quotes to Scrape\n\nQuotes to Scrape\nLogin\n“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”\nby\nAlbert Einstein\nTags:\nchange\ndeep-thoughts\nthinking\nworld\n“It is our choices, Harry, that show what we truly are, far more than our abilities.”\nby\nJ.K. Rowling\nTags:\nabilities\nchoices\n“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”\nby\nAlbert Einstein\nTags:\ninspirational\nlife\nlive\nmiracle\nmiracles\n“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”\nby\nJane Austen\nTags:\naliteracy\nbooks\nclassic\nhumor\n“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”\nby\nMarilyn Monroe\nTags:\nbe-yourself\ninspirational\n“Try not to become a man of success. Rather become a man of value.”\nby\nAlbert Einstein\nTags:\nadulthood\nsuccess\nvalue\n“It is better to be hated for what you are than to be loved for what you are not.”\nby\nAndré Gide\nTags:\nlife\nlove\n“I have not failed. I've just found 10,000 ways that won't work.”\nby\nThomas A. Edison\nTags:\nedison\nfailure\ninspirational\nparaphrased\n“A woman is like a tea bag; you never know how strong it is until it's in hot water.”\nby\nEleanor Roosevelt\nTags:\nmisattributed-eleanor-roosevelt\n“A day without sunshine is like, you know, night.”\nby\nSteve Martin\nTags:\nhumor\nobvious\nsimile\nNext\n→\nQuotes by:\nGoodReads.com\nMade with\n❤\nby\nZyte"

# %%
display_summary("https://quotes.toscrape.com/js/", contains_js=True)
# Out:
# This site is basically a quote vending machine.
#
# You get a scroll of famous quotes from Einstein, Rowling, Austen, Marilyn Monroe, Edison, etc., each with cutesy tag labels like “inspirational,” “humor,” and “failure,” plus pagination to see more. There’s a “Login” link pretending you might need an account to read sentences people have been copy-pasting since the dawn of Facebook.
#
# No news, no announcements—just philosophical sound bites and one Steve Martin joke to remind you not to take any of it too seriously.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
content = parse_letterboxd_rss("https://letterboxd.com/nandoconde/rss/")
print(content)
# Out:
# Letterboxd - nandoconde
#
# title: Juror #2, 2024 - ★★★★½
# link: https://letterboxd.com/nandoconde/film/juror-2/1/
# guid: letterboxd-review-1370670541
# pubDate: Sat, 27 Jun 2026 13:56:24 +1200
# watchedDate: 2026-06-27
# rewatch: Yes
# filmTitle: Juror #2
# filmYear: 2024
# memberRating: 4.5
# description: Tercera vez que la veo. Me ha gustado cuánto ha provocado a los chavales.
# A la luz de la jubilación oficial de Eastwood —que ya era conocida de sobra—, queda claro que su última película se aleja de cualquier tono crepuscular y busca siempre la apertura a nuevas formas de concebir el mundo. El que vio venir, ir, y volver el género western (la forma de vida de un continente entero, caída en el olvido en menos de 100 años), sugiere la fragilidad de nuestra sociedad, y duda de nuestra incapacidad moral de estar a la altura de las exigencias que vendrán.
# La respuesta, como la resolución de esta peli, queda en nuestras manos.
# creator: nandoconde
#
# title: Unforgiven, 1992 - ★★★★½
# link: https://letterboxd.com/nandoconde/film/unforgiven/
# guid: letterboxd-review-1358621423
# pubDate: Thu, 18 Jun 2026 01:13:00 +1200
# watchedDate: 2026-06-17
# rewatch: No
# filmTitle: Unforgiven
# filmYear: 1992
# memberRating: 4.5
# description: 91/100
# Recia como los hombres que describe, y con una historia tan árida como el territorio en que transita,
# Unforgiven
# es una película redonda que, como el mejor cine, deja con más preguntas que respuestas.
# ¿Por qué se casó la dulce chica con el rebelde asesino?
# ¿Por qué este salió de su retiro para luego pacíficamente volver a él?
# ¿Por qué nadie es capaz de abrir paso a la gracia y al perdón?
# Llevaba tiempo queriendo verla, ha estado a la altura de las expectativas.
# PD: otra película vista en cuatro tandas, me da que la vida de casado va a ser esta.
# creator: nandoconde
#
# title: Ocean Waves, 1993 - ★★★★
# link: https://letterboxd.com/nandoconde/film/ocean-waves/
# guid: letterboxd-review-1335658006
# pubDate: Sun, 31 May 2026 10:40:46 +1200
# watchedDate: 2026-05-30
# rewatch: No
# filmTitle: Ocean Waves
# filmYear: 1993
# memberRating: 4.0
# description: 81/100
# Un pequeño cuento para adolescentes enamoradizos, estilo Ghibli. ¿A quién no le va a gustar?
# Con una duración menor a la que el estudio acostumbra, y con una historia más compacta, no consigue el impacto emocional ni la profundidad de sus obras magnas. Pero con una buena animación, y una narración interesante para cualquiera que viva en el mundo, consigue hacernos pasar un buen rato y sonreír ante las vueltas de la vida.
# Quiero volver a Japón para andar por sus andenes, sus playas y sus calles, y contagiarme de su prisma tan especial para mirar el mundo.
# creator: nandoconde
#
# title: Redeeming Love, 2022 - ★★
# link: https://letterboxd.com/nandoconde/film/redeeming-love/
# guid: letterboxd-review-1301733129
# pubDate: Sun, 3 May 2026 10:13:26 +1200
# watchedDate: 2026-05-02
# rewatch: No
# filmTitle: Redeeming Love
# filmYear: 2022
# memberRating: 2.0
# description: 44/100
# El ritmo es terrible, pero hay un intento de historia de gracia divina que deja intuir que alguien en la producción ha experimentado algo en su interior.
# En fin, más mediocridades de la televisión pública.
# creator: nandoconde
#
# title: Project Hail Mary, 2026 - ★★★½
# link: https://letterboxd.com/nandoconde/film/project-hail-mary/
# guid: letterboxd-review-1299481952
# pubDate: Fri, 1 May 2026 18:07:37 +1200
# watchedDate: 2026-05-01
# rewatch: No
# filmTitle: Project Hail Mary
# filmYear: 2026
# memberRating: 3.5
# description: 74/100
# Molona, pero intrascendente.
# Mejor el libro, muchísimo mejor Interstellar.
# creator: nandoconde
#
# title: Ryuichi Sakamoto's Last Days, 2024 - ★★★★
# link: https://letterboxd.com/nandoconde/film/ryuichi-sakamotos-last-days/
# guid: letterboxd-review-1274195998
# pubDate: Fri, 10 Apr 2026 08:47:06 +1200
# watchedDate: 2026-04-09
# rewatch: No
# filmTitle: Ryuichi Sakamoto's Last Days
# filmYear: 2024
# memberRating: 4.0
# description: 83/100
# Hay dos momentos del documental que me arrasan. El primero, escuchar la pieza orquestal inacabada; solo en el cielo sabremos cómo suena la eternidad. El segundo es verle intentar dirigir la Tohoku Youth Orchestra a distancia, y ver cómo se rompe con el poema y al ver que, al igual que ya no tiene fuerzas para seguir dirigiendo, tampoco así para seguir con su vida.
# La realidad es soberana.
# Gracias, Señor, por el arte y los artistas.
# Sakamoto fue uno de los mejores.
# creator: nandoconde
#
# title: Wreck-It Ralph, 2012 - ★★★
# link: https://letterboxd.com/nandoconde/film/wreck-it-ralph/
# guid: letterboxd-review-1261711777
# pubDate: Wed, 1 Apr 2026 11:57:29 +1300
# watchedDate: 2026-03-31
# rewatch: No
# filmTitle: Wreck-It Ralph
# filmYear: 2012
# memberRating: 3.0
# description: 62/100
# Después de un primer acto rutinario, y a pesar de una resolución facilona, tiene alguna punchline que funciona y el mundo es muy imaginativo. Seguro que funciona con los pequeños, aunque no edifique mucho.
# Casarme con Alba ha abierto la puerta a un catálogo de referentes culturales que evitaba por pereza.
# creator: nandoconde
#
# title: The Virgin Suicides, 1999 - ★★★
# link: https://letterboxd.com/nandoconde/film/the-virgin-suicides/
# guid: letterboxd-review-1259823929
# pubDate: Tue, 31 Mar 2026 02:52:49 +1300
# watchedDate: 2026-03-30
# rewatch: No
# filmTitle: The Virgin Suicides
# filmYear: 1999
# memberRating: 3.0
# description: 64/100
# Aunque camina con astucia en el peligroso borde entre pretenciosa y genial, no despega nunca y acaba siendo aburrida.
# Aún así, Coppola tiene intuiciones fantásticas que merecen muchas más oportunidades.
# creator: nandoconde
#
# title: Zootopia, 2016 - ★★★½
# link: https://letterboxd.com/nandoconde/film/zootopia/
# guid: letterboxd-review-1247978460
# pubDate: Sun, 22 Mar 2026 12:52:57 +1300
# watchedDate: 2026-03-21
# rewatch: No
# filmTitle: Zootopia
# filmYear: 2016
# memberRating: 3.5
# description: 72/100
# No sé, a lo mejor espero poquito del cine actual. Pero esta película contada sin florituras me ha parecido más entretenida que la ganadora del Oscar de este año.
# Obviamente, vista por insistencia de Alba —que quería ver la 2, pero consideraba un crimen que no hubiera visto la primera—.
# creator: nandoconde
#
# title: Ponyo, 2008 - ★★★★½
# link: https://letterboxd.com/nandoconde/film/ponyo/
# guid: letterboxd-review-1237144655
# pubDate: Sat, 14 Mar 2026 05:19:19 +1300
# watchedDate: 2026-03-13
# rewatch: No
# filmTitle: Ponyo
# filmYear: 2008
# memberRating: 4.5
# description: 91/100
# La película más tierna de Ghibli. Como el miedo de Susuke por la fragilidad de la pequeña Ponyo, Miyazaki dirige con sumo cuidado para no contaminar ni rasgar la pequeña perla de película.
# Extremadamente accesible para todas las edades y condiciones, es sensorial y muy concreta en sus gestos. Su revolución es la ternura.
# Me quedo con la escena de las dos madres hablando, una apertura enorme para que entre la Gracia en la película.
# creator: nandoconde

# %%
# Step 1: Create your prompts

system_prompt = """You are a snarky assistant that analizes movie reviews 
from a certain user in letterboxd and provides a short description of what you think about
the user's taste in movies. Include also a recommendation of a movie that the user should watch.
Do it in spanish"""

user_prompt = """
    These are the reviews from the user {username}:

    {reviews}
"""

# Step 2: Make the messages list

def letterboxd_messages_for(user, reviews):
    return [
    { "role": "system", "content": system_prompt },
    { "role": "user", "content": user_prompt.format(username=user, reviews=reviews) }
    ]

# Step 3: Call OpenAI
# url must be like https://letterboxd.com/<username>/rss/

def llm_call(url):
    username = url.split("/")[-2]
    response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=letterboxd_messages_for(username, parse_letterboxd_rss(url))
    )
    return response.choices[0].message.content

# Step 4: print the result
# print(llm_call("https://letterboxd.com/jorgeubeda/films/reviews/"))

# %%
snarky_user_desc = llm_call("https://letterboxd.com/JorgitoUbeda/rss/")
display(Markdown(snarky_user_desc))
# Out:
# Tu gusto en cine es como ver a alguien comer palomitas con cuchillo y tenedor: infantil en la superficie, bastante fino por debajo.
#
# - Te flipan las pelis de animación (Toy Story, Zootopia, Ghibli…) pero no las ves como “para niños”, sino como arte serio.
# - Tienes debilidad por el terror raro / internet-core (Backrooms, Exit 8), pero más por la atmósfera y las ideas que por los jumpscares.
# - Te interesa mucho la dimensión social y ética: minería, crianza, adicciones… no ves las pelis en el vacío, las conectas con noticias, símbolos y tu propia experiencia.
# - Odias cordialmente al postureo intelectual tipo “me encanta porque no he entendido nada”, pero a la vez te curras lecturas bastante profundas (lo de *Weapons* es medio ensayo).
# - Tu escala de notas huele a “tengo criterio pero no quiero ir de crítico profesional”: casi todo entre 3,5 y 4,5, pocas cosas te parecen basura absoluta.
#
# En resumen: eres un friki del cine que combina animación, terror conceptual y drama con subtexto social, y que quiere que las pelis tengan algo que decir… pero sin tener que hacer un doctorado para entenderlas.
#
# **Recomendación para ti:**
# Mírate **Perfect Blue** (1997), de Satoshi Kon.
# ¿Por qué?
# - Animación, pero adulta y oscura.
# - Terror psicológico / paranoia que se presta a análisis sin ser puro postureo esotérico.
# - Crítica social sobre identidad, explotación y obsesión mediática: perfecto para tu vena “Weapons/Unknown Number” + tu odio a la gente que presume de no entender nada.

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
